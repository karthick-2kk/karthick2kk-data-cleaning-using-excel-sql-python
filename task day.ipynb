# %%
import oracledb
connection = oracledb.connect(
    user="karthick", password="karthick",dsn = "localhost:1521/xe")
print("Connected")
# Out:
# Connected

# %%
pip install oracledb
# Out:
# ...
#
# ...

# %%
import pandas as pd
query = "select * from employee_sales_dataset"
df = pd.read_sql(query,con= connection)
print (df)
# Out:
# C:\Users\Deris\AppData\Local\Temp\ipykernel_21212\502257201.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query,con= connection)
#      EMPLOYEE_ID FIRST_NAME LAST_NAME  AGE  GENDER BLOOD_GROUP  \
# 0        EMP0066    Harshil    Sekhon   24   Other         AB+
# 1        EMP0067     Saanvi     Morar   33   Other          A-
# 2        EMP0068   Aradhana       Lad   48    Male         AB+
# 3        EMP0069    Bhavani       Dey   30    Male         AB+
# 4        EMP0070       Reva  Malhotra   31  Female         AB+
# ...          ...        ...       ...  ...     ...         ...
# 1495     EMP1408    Mekhala      Kota   28    Male         AB+
# 1496     EMP1409        Max    Mangat   36   Other         AB+
# 1497     EMP1410   Pratyush      Char   42  Female          O-
# ...
